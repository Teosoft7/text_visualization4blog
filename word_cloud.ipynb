# %%
from wordcloud import WordCloud
from wordcloud import STOPWORDS

# %matplotlib inline
import matplotlib.pyplot as plt 
import pandas as pd

# %%
texts = 'Dog Cat Animal Carmel Snake'
wordcloud = WordCloud()
wordcloud = wordcloud.generate_from_text(texts)

# %%
texts = ['이것 은 예문 입니다', '여러분 의 문장을 넣 으세요']
keywords = {'이것':5, '예문':3, '단어':5, '빈도수':3}

# wordcloud = wordcloud.generate_from_text(texts)
# wordcloud = wordcloud.generate_from_frequencies(keywords)

# %%
with open('slacks.txt') as f:
    slack_text = f.read()

# %%
stopwords = set(STOPWORDS) 
stopwords.add('https')
stopwords.add('learn')
stopwords.add('co')

# %%
wordcloud = WordCloud(width = 1200, height = 1200, 
                font_path='/Library/Fonts/AppleGothic.ttf',
                background_color ='white', 
                stopwords = stopwords,                 
                min_font_size = 10).generate_from_text(slack_text)

# %%
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud, interpolation="bilinear") 
plt.axis("off") 
plt.tight_layout(pad = 4) 

plt.show()
